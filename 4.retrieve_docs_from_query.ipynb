# %%
storagegrid_dict = {
    
   "Get started with StorageGRID system" :[
    "What is StorageGRID:NetApp StorageGRID is a software-defined object storage solution. Supports public, private, and hybrid multicloud environments with native Amazon S3 API support.Focuses on automated lifecycle management to manage unstructured data cost-effectively." ,
    "Core Features: Massively scalable, metadata-driven lifecycle management.Integration with AWS, Azure, and OpenStack Swift (support for Swift is deprecated).Flexible data protection with replication and erasure coding." ,
    "Hybrid Cloud Capabilities: Policy-driven data management for storage optimization.Integration with external storage like Amazon S3 Glacier, Google Cloud, and Azure Blob Storage.CloudMirror replication and event notifications for external service integration." ,
    "Data Protection: Supports replication and erasure coding to protect object data.ILM (Information Lifecycle Management) for data storage, protection, and deletion policies.S3 Object Lock for data retention and legal holds." ,
    "Networking & Management:Three network types: Grid Network (mandatory), Admin Network (optional), Client Network (optional).High availability and virtual IP support for redundancy.Grid Manager for configuration and monitoring, Tenant Manager for storage account management."
],
    "Install,Upgrade and hotflix StorageGRID": [
        "Installation Overview: Describes the steps required to install the StorageGRID system, including configuring nodes and downloading the recovery package.",
        "Post-Installation Guidelines: Provides instructions for tasks such as DHCP addressing and network configuration changes after completing grid node deployment and configuration.",
        "Virtual Machine Resource Reservation: Details the process of adjusting resources for virtual machines to ensure sufficient RAM and CPU for each grid node.",
        "Temporary Installation Password: Explains how to set and manage a temporary installation password during the deployment of a VMware node.",
        "Upgrading StorageGRID Software: Offers an overview and step-by-step instructions for upgrading the StorageGRID system to a new release.",
        "StorageGRID Installation API: Introduces the API used for performing installation tasks, including sections like config, grid, nodes, provision, recovery, recovery-package, schemas, and sites.",
        "Configuring and Managing Nodes: Discusses creating and placing node configuration files for Ubuntu or Debian deployments, including naming conventions and the content of configuration files.",
        "Troubleshooting Installation Issues: Provides guidance on accessing installation log files and troubleshooting installation problems.",
        "Integration and Configuration Tasks: Lists required and optional tasks after installation, such as creating tenant accounts, configuring groups and user accounts, integrating S3 or Swift API client applications, and configuring ILM rules and policies.",
        "Documentation and Support: Mentions the documentation site for appliances and support for FIPS 140-2 validated cryptography."
    ],
    "Configure and manage a storageGRID system": [
        "Grid Management API: Describes the use of the Swagger API platform to perform real-time operations in StorageGRID.",
        "Monitoring Data Migration: Provides guidelines for monitoring attributes and managing data migration in the StorageGRID system.",
        "Information Lifecycle Management (ILM): Covers ILM rules and policies for managing object data throughout its lifecycle in StorageGRID.",
        "Admin Group Permissions: Explains the creation and management of admin user groups, including assigning permissions and managing access modes.",
        "Log Files and System Status: Details various log files and system status files, including their contents and how to interpret them."
    ],
    "Use StorageGRID tenant and clients": [
        "Tenant Account Overview: Describes the purpose and capabilities of a tenant account in StorageGRID.",
        "Creating a Tenant Account: Steps and requirements for a StorageGRID grid administrator to create a tenant account.",
        "Configuring S3 Tenants: Tasks that can be performed using the Tenant Manager for S3 tenant accounts.",
        "Configuring Swift Tenants: Tasks that can be performed using the Tenant Manager for Swift tenant accounts.",
        "Signing In and Out: Procedures for signing in and out of the Tenant Manager, including both SSO and non-SSO methods.",
        "Tenant Manager Dashboard: Overview of the dashboard's features and the information it displays about tenant accounts.",
        "Storage and Quota Usage: Details on how storage usage and quotas are monitored and managed."
    ],
    "Monitor and troubleshoot a storageGRID system": [
        "Monitor StorageGRID System: Regular monitoring of the StorageGRID system ensures optimal performance and early detection of issues.",
        "View and Manage the Dashboard: The dashboard provides an overview of system activities and allows for customization to fit specific monitoring needs.",
        "View the Nodes Page: The Nodes page offers detailed metrics for the entire grid, each site, and individual nodes, helping in deeper analysis of system performance.",
        "View Log Files: Log files can be accessed and reviewed to diagnose and troubleshoot issues within the StorageGRID system.",
        "Manage Alerts: Alerts help in detecting, evaluating, and resolving issues with customizable notifications and rules for better system management.",
        "Use SNMP for Monitoring: SNMP can be configured to monitor the StorageGRID system and send notifications based on specific events or thresholds.",
        "Configure Audit Messages and Log Destinations: Audit messages and log destinations can be set up to track system activities and store logs for compliance and review.",
        "Use an External Syslog Server: An external syslog server can be used to collect audit information for centralized logging and monitoring.",
        "Tenant Activity: Monitoring tenant activity helps in understanding resource usage and managing tenant-specific performance issues.",
        "Networking and System Resources: Keeping an eye on networking and system resources ensures that the infrastructure supports the StorageGRID operations effectively."
    ],
    "Expand a Grid": [
        "Plan StorageGRID Expansion: Strategies and considerations for planning an effective expansion of the StorageGRID system.",
        "Guidelines for Adding Storage Volumes: Detailed instructions and limitations on how to add storage volumes to different types of Storage Nodes.",
        "Guidelines for Adding Storage Nodes: Best practices and limitations for adding new Storage Nodes to existing sites.",
        "Guidelines for ADC Service on Storage Nodes: Recommendations for configuring the Administrative Domain Controller (ADC) service on new Storage Nodes.",
        "Add Storage Capacity for Replicated Objects: Considerations for expanding storage to support replicated object data according to the ILM policy.",
        "Add Storage Capacity for Erasure-Coded Objects: Planning and guidelines for adding storage to support erasure-coded object data.",
        "Considerations for Rebalancing Erasure-Coded Data: Insights into the EC rebalance procedure necessary when adding new Storage Nodes to handle erasure-coded data.",
        "Add Metadata Capacity: Instructions on expanding metadata capacity by adding new Storage Nodes to each site."
    ],
    "Maintain a Storage GRID": [
        "Grid Maintenance Overview: Covers tasks like decommissioning nodes, renaming the grid, and maintaining networks.",
        "Maintenance Procedures for Appliances: Provides guidelines for maintaining StorageGRID appliances according to specific hardware instructions.",
        "Download Recovery Package: Instructions on downloading a Recovery Package to restore the system in case of a failure.",
        "Decommission Nodes or Site: Steps to permanently remove grid nodes or an entire site from the StorageGRID system.",
        "Grid Node Decommission Overview: Detailed process for removing one or more grid nodes, except the primary Admin Node.",
        "Considerations for Decommissioning Storage Nodes: Important factors to consider before decommissioning Storage Nodes to ensure proper system functioning.",
        "Connected and Disconnected Site Decommission: Differentiates between removing a connected operational site and a disconnected failed site.",
        "Add or Update Display Names: Procedures for renaming the grid, sites, or nodes without affecting StorageGRID operations.",
        "Monitoring Erasure-Coded Data Repairs: Steps to monitor and retry repairs for erasure-coded data to ensure data integrity.",
        "Decommissioning Connected Grid Nodes: Guidelines for safely decommissioning nodes that are still connected to the grid."
    ],
    "Recovery or Replace Nodes": [
        "Repairing Node Failures: Instructions for repairing failed nodes and tracking repair status using specific commands and tools.",
        "Checking Storage State After Recovery: Steps to verify that the desired state of a recovered storage node is set to online and remains online after a server restart.",
        "Recovering from Storage Volume Failures: Procedures for recovering software-based storage nodes with failed volumes while the system drive remains intact.",
        "Warnings for Storage Volume Recovery: Important warnings and considerations to review before beginning the recovery of failed storage volumes.",
        "Rebuilding the Cassandra Database: Steps to rebuild the Cassandra database as part of the volume recovery process.",
        "Using Recovery Scripts: Details on running specific recovery scripts like sn-remount-volumes and sn-recovery-postinstall.sh to remount, reformat storage volumes, and start services on the storage node.",
        "Restoring Object Data: Guidelines for restoring object data using Grid Manager and monitoring the restoration process.",
        "Monitoring Repair Jobs: Methods to monitor the status of repair jobs for both replicated and erasure-coded data, including using specific commands and tools within the Grid Manager.",
        "Erasure-Coded Data Repair: Specific instructions to monitor and retry failed erasure-coded data repair requests.",
        "Restoration Progress and History: Viewing the progress and history of volume restorations within Grid Manager, including handling failed restoration attempts."
    ]
}


storagegrid_dict.values()
sentences=[]
for i in storagegrid_dict.values():
    sentences=sentences+i

sentence_identifier=sentences

# %%
sentence_identifier
# Out:
# ['What is StorageGRID:NetApp StorageGRID is a software-defined object storage solution. Supports public, private, and hybrid multicloud environments with native Amazon S3 API support.Focuses on automated lifecycle management to manage unstructured data cost-effectively.',
#  'Core Features: Massively scalable, metadata-driven lifecycle management.Integration with AWS, Azure, and OpenStack Swift (support for Swift is deprecated).Flexible data protection with replication and erasure coding.',
#  'Hybrid Cloud Capabilities: Policy-driven data management for storage optimization.Integration with external storage like Amazon S3 Glacier, Google Cloud, and Azure Blob Storage.CloudMirror replication and event notifications for external service integration.',
#  'Data Protection: Supports replication and erasure coding to protect object data.ILM (Information Lifecycle Management) for data storage, protection, and deletion policies.S3 Object Lock for data retention and legal holds.',
#  'Networking & Management:Three network types: Grid Network (mandatory), Admin Network (optional), Client Network (optional).High availability and virtual IP support for redundancy.Grid Manager for configuration and monitoring, Tenant Manager for storage account management.',
#  'Installation Overview: Describes the steps required to install the StorageGRID system, including configuring nodes and downloading the recovery package.',
#  'Post-Installation Guidelines: Provides instructions for tasks such as DHCP addressing and network configuration changes after completing grid node deployment and configuration.',
#  'Virtual Machine Resource Reservation: Details the process of adjusting resources for virtual machines to ensure sufficient RAM and CPU for each grid node.',
#  'Temporary Installation Password: Explains how to set and manage a temporary installation password during the deployment of a VMware node.',
#  'Upgrading StorageGRID Software: Offers an overview and step-by-step instructions for upgrading the StorageGRID system to a new release.',
#  'StorageGRID Installation API: Introduces the API used for performing installation tasks, including sections like config, grid, nodes, provision, recovery, recovery-package, schemas, and sites.',
#  'Configuring and Managing Nodes: Discusses creating and placing node configuration files for Ubuntu or Debian deployments, including naming conventions and the content of configuration files.',
#  'Troubleshooting Installation Issues: Provides guidance on accessing installation log files and troubleshooting installation problems.',
#  'Integration and Configuration Tasks: Lists required and optional tasks after installation, such as creating tenant accounts, configuring groups and user accounts, integrating S3 or Swift API client applications, and configuring ILM rules and policies.',
#  'Documentation and Support: Mentions the documentation site for appliances and support for FIPS 140-2 validated cryptography.',
#  'Grid Management API: Describes the use of the Swagger API platform to perform real-time operations in StorageGRID.',
#  'Monitoring Data Migration: Provides guidelines for monitoring attributes and managing data migration in the StorageGRID system.',
#  'Information Lifecycle Management (ILM): Covers ILM rules and policies for managing object data throughout its lifecycle in StorageGRID.',
#  'Admin Group Permissions: Explains the creation and management of admin user groups, including assigning permissions and managing access modes.',
#  'Log Files and System Status: Details various log files and system status files, including their contents and how to interpret them.',
#  'Tenant Account Overview: Describes the purpose and capabilities of a tenant account in StorageGRID.',
#  'Creating a Tenant Account: Steps and requirements for a StorageGRID grid administrator to create a tenant account.',
#  'Configuring S3 Tenants: Tasks that can be performed using the Tenant Manager for S3 tenant accounts.',
#  'Configuring Swift Tenants: Tasks that can be performed using the Tenant Manager for Swift tenant accounts.',
#  'Signing In and Out: Procedures for signing in and out of the Tenant Manager, including both SSO and non-SSO methods.',
#  "Tenant Manager Dashboard: Overview of the dashboard's features and the information it displays about tenant accounts.",
#  'Storage and Quota Usage: Details on how storage usage and quotas are monitored and managed.',
#  'Monitor StorageGRID System: Regular monitoring of the StorageGRID system ensures optimal performance and early detection of issues.',
#  'View and Manage the Dashboard: The dashboard provides an overview of system activities and allows for customization to fit specific monitoring needs.',
#  'View the Nodes Page: The Nodes page offers detailed metrics for the entire grid, each site, and individual nodes, helping in deeper analysis of system performance.',
#  'View Log Files: Log files can be accessed and reviewed to diagnose and troubleshoot issues within the StorageGRID system.',
#  'Manage Alerts: Alerts help in detecting, evaluating, and resolving issues with customizable notifications and rules for better system management.',
#  'Use SNMP for Monitoring: SNMP can be configured to monitor the StorageGRID system and send notifications based on specific events or thresholds.',
#  'Configure Audit Messages and Log Destinations: Audit messages and log destinations can be set up to track system activities and store logs for compliance and review.',
#  'Use an External Syslog Server: An external syslog server can be used to collect audit information for centralized logging and monitoring.',
#  'Tenant Activity: Monitoring tenant activity helps in understanding resource usage and managing tenant-specific performance issues.',
#  'Networking and System Resources: Keeping an eye on networking and system resources ensures that the infrastructure supports the StorageGRID operations effectively.',
#  'Plan StorageGRID Expansion: Strategies and considerations for planning an effective expansion of the StorageGRID system.',
#  'Guidelines for Adding Storage Volumes: Detailed instructions and limitations on how to add storage volumes to different types of Storage Nodes.',
#  'Guidelines for Adding Storage Nodes: Best practices and limitations for adding new Storage Nodes to existing sites.',
#  'Guidelines for ADC Service on Storage Nodes: Recommendations for configuring the Administrative Domain Controller (ADC) service on new Storage Nodes.',
#  'Add Storage Capacity for Replicated Objects: Considerations for expanding storage to support replicated object data according to the ILM policy.',
#  'Add Storage Capacity for Erasure-Coded Objects: Planning and guidelines for adding storage to support erasure-coded object data.',
#  'Considerations for Rebalancing Erasure-Coded Data: Insights into the EC rebalance procedure necessary when adding new Storage Nodes to handle erasure-coded data.',
#  'Add Metadata Capacity: Instructions on expanding metadata capacity by adding new Storage Nodes to each site.',
#  'Grid Maintenance Overview: Covers tasks like decommissioning nodes, renaming the grid, and maintaining networks.',
#  'Maintenance Procedures for Appliances: Provides guidelines for maintaining StorageGRID appliances according to specific hardware instructions.',
#  'Download Recovery Package: Instructions on downloading a Recovery Package to restore the system in case of a failure.',
#  'Decommission Nodes or Site: Steps to permanently remove grid nodes or an entire site from the StorageGRID system.',
#  'Grid Node Decommission Overview: Detailed process for removing one or more grid nodes, except the primary Admin Node.',
#  'Considerations for Decommissioning Storage Nodes: Important factors to consider before decommissioning Storage Nodes to ensure proper system functioning.',
#  'Connected and Disconnected Site Decommission: Differentiates between removing a connected operational site and a disconnected failed site.',
#  'Add or Update Display Names: Procedures for renaming the grid, sites, or nodes without affecting StorageGRID operations.',
#  'Monitoring Erasure-Coded Data Repairs: Steps to monitor and retry repairs for erasure-coded data to ensure data integrity.',
#  'Decommissioning Connected Grid Nodes: Guidelines for safely decommissioning nodes that are still connected to the grid.',
#  'Repairing Node Failures: Instructions for repairing failed nodes and tracking repair status using specific commands and tools.',
#  'Checking Storage State After Recovery: Steps to verify that the desired state of a recovered storage node is set to online and remains online after a server restart.',
#  'Recovering from Storage Volume Failures: Procedures for recovering software-based storage nodes with failed volumes while the system drive remains intact.',
#  'Warnings for Storage Volume Recovery: Important warnings and considerations to review before beginning the recovery of failed storage volumes.',
#  'Rebuilding the Cassandra Database: Steps to rebuild the Cassandra database as part of the volume recovery process.',
#  'Using Recovery Scripts: Details on running specific recovery scripts like sn-remount-volumes and sn-recovery-postinstall.sh to remount, reformat storage volumes, and start services on the storage node.',
#  'Restoring Object Data: Guidelines for restoring object data using Grid Manager and monitoring the restoration process.',
#  'Monitoring Repair Jobs: Methods to monitor the status of repair jobs for both replicated and erasure-coded data, including using specific commands and tools within the Grid Manager.',
#  'Erasure-Coded Data Repair: Specific instructions to monitor and retry failed erasure-coded data repair requests.',
#  'Restoration Progress and History: Viewing the progress and history of volume restorations within Grid Manager, including handling failed restoration attempts.']

# %%
api_token="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"
API_URL = "https://api-inference.huggingface.co/models/sentence-transformers/msmarco-distilbert-base-tas-b"
headers = {"Authorization": f"Bearer {api_token}"}

import requests

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

def get_key_from_value(d, value):
    for key, val in d.items():
        if val == value:
            return key
    return None 



# FInd the list of topics that can contain the answer for the user query
def topic_finder(question,topics):

    data = query(
        {
            "inputs": {
                "source_sentence":question,
                "sentences":topics
            }
        })
    print(len(data))
    data_Score=[]

    for i in range(0,len(data)):
        # print(data[i],topics[i])
        data_Score.append((data[i],topics[i]))

    # Sort the list of tuples by the first element in descending order
    data_ = sorted(data_Score, key=lambda x: x[0], reverse=True)

    # Extract the top 3 values and sentences
    top_10 = data_[:80]
    list_subtopics=[top_10[i][1] for i in range(0,5)]
    
    topic_list=[]
    for i in storagegrid_dict.values():
        for j in list_subtopics:
            if j in i:
                topic_list.append(get_key_from_value(storagegrid_dict,i))
    
    return list(set(topic_list))

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_nvidia import ChatNVIDIA
from langchain_core.output_parsers import StrOutputParser
llm = ChatNVIDIA(model="meta/llama-3.1-405b-instruct",temperature=0,
                 nvidia_api_key="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")
# from langgraph.graph import StateGraph
from typing import TypedDict, List, Annotated
from langchain_openai import AzureChatOpenAI
import operator
# from langgraph.graph import END
import os
# from langgraph.graph import END, StateGraph, START
from langchain_community.document_loaders import PyPDFLoader
# from langgraph.graph import END, StateGraph, START
from langchain_openai import OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from typing import List
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from typing_extensions import TypedDict
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_openai import AzureOpenAIEmbeddings

import re,json
import getpass
import os
import re

# nvidia_api_key=
# if not os.environ.get("NVIDIA_API_KEY", "").startswith("nvapi-"):
#     nvidia_api_key = getpass.getpass("Enter your NVIDIA API key: ")
# #     assert nvidia_api_key.startswith("nvapi-"), f"{nvidia_api_key[:5]}... is not a valid key"
# os.environ["NVIDIA_API_KEY"] = nvidia_api_key

question="TCP / Application Protocol Support"
def query_fromer(query):

    llm = ChatNVIDIA(model="meta/llama-3.1-405b-instruct",temperature=0,
                    nvidia_api_key="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")
    messages = [
        SystemMessage(content=f"""You are a helpful assistant in breaking down the customers-provided queries from the NetApp Storage Grid Data Storage Management System.

    You will be provided with a query.You have to provide the output in json format

    Follow the instructions to provide the output.

    1. Understand the question .
    2. break it into multiple questions if required.
    3. Provide the questions as output. STRICTLY Provide the output in json format with only the questions.
        """),
        HumanMessage(content=f"Here is the question:{query}"),
    ]
    chain=llm | StrOutputParser()
    questions=chain.invoke(messages)
    
    result = llm.invoke(f"You are a json extractor. Extract the json data from the given string {questions}.OUTPUT should be STRICTLY in JSON Format. only the text within curly braces")

    
    
    match = re.search(r'```\s*({.*?})\s*```',result.content, re.DOTALL)
    if match:
        extracted_json = match.group(1)
        print(extracted_json)

    queries=json.loads(extracted_json)

    query_list = queries["questions"]

    return query_list
# Out:
# d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3577: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from langchain_astradb import AstraDBVectorStore

# %%
import os
os.environ["OPENAI_API_VERSION"] = "2024-02-01"
os.environ["AZURE_OPENAI_ENDPOINT"] = "https://expazure-openai.openai.azure.com/"
os.environ["AZURE_OPENAI_API_KEY"] = "0f5cb3c2ad3d40d9a76142c3f49cad9f"

# %%
def get_relevant_data(topics,question):
    docs_retrieved=[]
    embeddings = AzureOpenAIEmbeddings(
        azure_deployment="embeddingada",
        openai_api_version="2024-02-01",
        api_key="7NfDltek1fOyeUm4UDN9Ng8wmagQxtd54CfuS4TcCk6tvtu8nTrEJQQJ99ALAC4f1cMXJ3w3AAABACOGHgtJ",
        azure_endpoint= "https://expazure-openai.openai.azure.com/"
    )
    vector_store = AstraDBVectorStore(
            collection_name="rpf_data",
            embedding=embeddings,
            api_endpoint="https://fe1e130e-4fcb-43ed-a3c4-a87258f9a9e6-us-east-2.apps.astra.datastax.com",
            token="AstraCS:apyneBXFJQyZgFlXZNmSZNiv:8231981b7864751892f805731b6817ae1ae4e060fc74eb3ed82d1b56d12b026d",
            namespace="default_keyspace",
        )
    for topic in topics:
        results = vector_store.similarity_search(
                f"{question}",
                k=3,
                filter={"topic": f"{topic}"},
            )

        docs_retrieved.append(results)

    return docs_retrieved

    #     metadata= [item for sublist in docs_retrieved for item in sublist]
            
    # return metadata

# %%
topic_finder(question='this is the',topics=sentence_identifier)
# Out:
# 65
# ['Get started with StorageGRID system',
#  'Maintain a Storage GRID',
#  'Configure and manage a storageGRID system',
#  'Monitor and troubleshoot a storageGRID system']

# %%
# queries

# %%
question="Compression and deduplication capabilities"


queries=query_fromer(query=question)

topics=[]
for i in range(0,len(queries)):
               topics.append(topic_finder(question=queries[i],topics=sentence_identifier))

query_topic_dict={}
for i in range(0,len(topics)):
    query_topic_dict[queries[i]]=topics[i]

query_topic_dict

print(query_topic_dict)

documents_metadata=[]
for key,value in query_topic_dict.items():
        documents_metadata.append(get_relevant_data(key,value))
# Out:
# {
#   "questions": [
#     "What are the compression capabilities of the NetApp Storage Grid Data Storage Management System?",
#     "What are the deduplication capabilities of the NetApp Storage Grid Data Storage Management System?",
#     "How do compression and deduplication work together in the NetApp Storage Grid Data Storage Management System?"
#   ]
# }
# 65
# 65
# 65
# {'What are the compression capabilities of the NetApp Storage Grid Data Storage Management System?': ['Use StorageGRID tenant and clients', 'Get started with StorageGRID system', 'Expand a Grid'], 'What are the deduplication capabilities of the NetApp Storage Grid Data Storage Management System?': ['Maintain a Storage GRID', 'Get started with StorageGRID system', 'Configure and manage a storageGRID system', 'Expand a Grid', 'Monitor and troubleshoot a storageGRID system'], 'How do compression and deduplication work together in the NetApp Storage Grid Data Storage Management System?': ['Recovery or Replace Nodes', 'Install,Upgrade and hotflix StorageGRID', 'Get started with StorageGRID system', 'Expand a Grid']}
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[36], line 20
#      18 documents_metadata=[]
#      19 for key,value in query_topic_dict.items():
# ---> 20         documents_metadata.append(get_relevant_data(key,value))
#
# Cell In[35], line 9, in get_relevant_data(topics, question)
#       2 docs_retrieved=[]
#       3 embeddings = AzureOpenAIEmbeddings(
#       4     azure_deployment="embeddingada",
#       5     openai_api_version="2024-02-01",
#       6     api_key="0f5cb3c2ad3d40d9a76142c3f49cad9f",
#       7     azure_endpoint= "https://expazure-openai.openai.azure.com/"
#       8 )
# ----> 9 vector_store = AstraDBVectorStore(
#      10         collection_name="rpf_data",
#      11         embedding=embeddings,
#      12         api_endpoint="https://fe1e130e-4fcb-43ed-a3c4-a87258f9a9e6-us-east-2.apps.astra.datastax.com",
#      13         token="AstraCS:apyneBXFJQyZgFlXZNmSZNiv:8231981b7864751892f805731b6817ae1ae4e060fc74eb3ed82d1b56d12b026d",
#      14         namespace="default_keyspace",
#      15     )
#      16 for topic in topics:
#      17     results = vector_store.similarity_search(
#      18             f"{question}",
#      19             k=3,
#      20             filter={"topic": f"{topic}"},
#      21         )
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\langchain_astradb\vectorstores.py:558, in AstraDBVectorStore.__init__(self, collection_name, embedding, token, api_endpoint, environment, namespace, metric, batch_size, bulk_insert_batch_concurrency, bulk_insert_overwrite_concurrency, bulk_delete_concurrency, setup_mode, pre_delete_collection, metadata_indexing_include, metadata_indexing_exclude, collection_indexing_policy, collection_vector_service_options, collection_embedding_api_key, content_field, ignore_invalid_documents, autodetect_collection, ext_callers, component_name, astra_db_client, async_astra_db_client)
#     554 logger.info(
#     555     "vector store default init, collection '%s'", self.collection_name
#     556 )
#     557 _setup_mode = SetupMode.SYNC if setup_mode is None else setup_mode
# --> 558 _embedding_dimension = self._prepare_embedding_dimension(_setup_mode)
#     559 # determine vectorize/nonvectorize
#     560 has_vectorize = self.collection_vector_service_options is not None
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\langchain_astradb\vectorstores.py:704, in AstraDBVectorStore._prepare_embedding_dimension(self, setup_mode)
#     701 # case of setup_mode = SetupMode.SYNC, SetupMode.OFF
#     702 if self.embedding_dimension is None:
#     703     self.embedding_dimension = len(
# --> 704         self._get_safe_embedding().embed_query(
#     705             text="This is a sample sentence."
#     706         )
#     707     )
#     708 return self.embedding_dimension
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:629, in OpenAIEmbeddings.embed_query(self, text)
#     620 def embed_query(self, text: str) -> List[float]:
#     621     """Call out to OpenAI's embedding endpoint for embedding query text.
#     622
#     623     Args:
#    (...)
#     627         Embedding for the text.
#     628     """
# --> 629     return self.embed_documents([text])[0]
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:588, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     585 # NOTE: to keep things simple, we assume the list may contain texts longer
#     586 #       than the maximum context and use length-safe embedding function.
#     587 engine = cast(str, self.deployment)
# --> 588 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:483, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     481 batched_embeddings: List[List[float]] = []
#     482 for i in _iter:
# --> 483     response = self.client.create(
#     484         input=tokens[i : i + _chunk_size], **self._invocation_params
#     485     )
#     486     if not isinstance(response, dict):
#     487         response = response.model_dump()
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\openai\resources\embeddings.py:125, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     119         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     120             base64.b64decode(data), dtype="float32"
#     121         ).tolist()
#     123     return obj
# --> 125 return self._post(
#     126     "/embeddings",
#     127     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     128     options=make_request_options(
#     129         extra_headers=extra_headers,
#     130         extra_query=extra_query,
#     131         extra_body=extra_body,
#     132         timeout=timeout,
#     133         post_parser=parser,
#     134     ),
#     135     cast_to=CreateEmbeddingResponse,
#     136 )
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File d:\Hackthon\NetApp StorageGrid\.venv\Lib\site-packages\openai\_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1061         err.response.read()
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# AuthenticationError: Error code: 401 - {'statusCode': 401, 'message': 'Unauthorized. Access token is missing, invalid, audience is incorrect (https://cognitiveservices.azure.com), or have expired.'}

# %%
data={'What are the compression capabilities of the NetApp Storage Grid Data Storage Management System?': ['Use StorageGRID tenant and clients', 'Get started with StorageGRID system', 'Expand a Grid'], 
      'What are the deduplication capabilities of the NetApp Storage Grid Data Storage Management System?': ['Maintain a Storage GRID', 'Get started with StorageGRID system', 'Configure and manage a storageGRID system', 'Expand a Grid', 'Monitor and troubleshoot a storageGRID system'], 
      'How do compression and deduplication work together in the NetApp Storage Grid Data Storage Management System?': ['Recovery or Replace Nodes', 'Install,Upgrade and hotflix StorageGRID', 'Get started with StorageGRID system', 'Expand a Grid']}

# %%
# topics=[]
# for i in range(0,len(queries)):
#                topics.append(topic_finder(question=queries[i],topics=sentence_identifier))

# query_topic_dict={}
# for i in range(0,len(topics)):
#     query_topic_dict[queries[i]]=topics[i]

# query_topic_dict

documents_metadata=[]
for key,value in data.items():
        documents_metadata.append(get_relevant_data(topics=value,question=key))

# %%
# topics=['Use StorageGRID tenant and clients', 'Get started with StorageGRID system', 'Expand a Grid']
# question='What are the compression capabilities of the NetApp Storage Grid Data Storage Management System?'

# get_relevant_data(topics=topics, question=question)
documents_metadata
# Out:
# [[[Document(id='3c5e9193-5bf2-4b16-9478-c7f613520c4c', metadata={'type': 'text', 'topic': 'Use StorageGRID tenant and clients'}, page_content='StorageGRID S3 REST API to manage any existing legacy Compliant buckets. • Use S3 REST API to configure S3 Object Lock • Manage objects with ILM • NetApp Knowledge Base: How to manage legacy Compliant buckets in StorageGRID 11.5 Deprecated'),
#    Document(id='3ad6d446-a769-4bc1-995d-66b68f668da0', metadata={'type': 'text', 'topic': 'Use StorageGRID tenant and clients'}, page_content='be saved to several data centers for a certain number of years. Contact your NetApp Professional Services consultant or StorageGRID administrator if you need to understand how the grid’s ILM rules and policies will affect the objects in your Swift'),
#    Document(id='b4b4f649-69de-432f-ba17-e1edb95afcc2', metadata={'base64_path': 'Extracted_Data\\4.UseStorageGRID tenant and clients\\page_4\\page_4_img_1_base64.txt', 'type': 'image', 'topic': 'Use StorageGRID tenant and clients'}, page_content='The image shows a screenshot of the NetApp StorageGRID Grid Manager sign-in page. The page has a white background with black text and blue accents.\n\nAt the top of the page, there is a logo for NetApp StorageGRID, followed by the title "Grid Manager" in large font. Below the title, there are two input fields: one for the username and one for the password. The username field is labeled "Username" and has a placeholder text that reads "|". The password field is labeled "Password" and does not have any placeholder text.\n\nBelow the input fields, there is a blue button that reads "Sign in". To the left of this button, there is a link that reads "Tenant sign in" in blue text within a green rectangle. This link is likely used to access the Tenant Manager sign-in page.\n\nAt the bottom of the page, there are two links: one that reads "NetApp support" and another that reads "NetApp.com". These links are likely used to access additional resources or support information.\n\nOverall, the image appears to be a screenshot of a web-based application used for managing storage grids. The page is designed to allow users to sign in to their accounts using their usernames and passwords.')],
#   [Document(id='742dad94-b43b-47b0-b397-190e17eeaa11', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.'),
#    Document(id='b4a70c6b-86d3-48b9-b16a-56969f447e64', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='to learn about the available appliances: â€¢ StorageGRID Appliance Documentation â€¢ NetApp Hardware Universe 11'),
#    Document(id='92041416-820b-452a-aac4-d509f4ba6821', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='collect data Work with your NetApp account representative to understand the options and to plan your new StorageGRID system. Consider these types of questions: â€¢ How much object data do you expect to store initially and over time? â€¢ How many')],
#   [Document(id='dd0370fc-6a29-4289-b66d-7894edb16bd6', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the'),
#    Document(id='62c51cf1-08be-4855-84e7-51cbb047189d', metadata={'base64_path': 'Extracted_Data\\6.Expand a Grid\\page_20\\page_20_img_1_base64.txt', 'type': 'image', 'topic': 'Expand a Grid'}, page_content='The image shows a screenshot of the StorageGRID system\'s Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a table titled "Disk devices" that lists various disk devices, including their names, worldwide names, I/O load, read rates, write rates, and other relevant information.\n\nBelow this table is another table titled "Volumes" that lists the mount points for each volume, along with their status, size, available space, and write cache status. The bottom section of the image shows a table titled "Object stores" that lists the object stores, including their IDs, sizes, available space, replicated data, EC data, object data percentages, and health status.\n\nOverall, the image provides a comprehensive view of the storage nodes and their associated volumes and object stores, allowing administrators to monitor and manage the system\'s storage capacity and performance.'),
#    Document(id='275a28d1-fc4f-4f9c-ad57-bd7a993f206c', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='About this task You must perform expansion operations using the version of StorageGRID that is currently running on the grid. Steps 1. Go to NetApp Downloads: StorageGRID. 2. Select the version of StorageGRID that is currently running on the grid. 3.')]],
#  [[],
#   [Document(id='742dad94-b43b-47b0-b397-190e17eeaa11', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.'),
#    Document(id='b4a70c6b-86d3-48b9-b16a-56969f447e64', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='to learn about the available appliances: â€¢ StorageGRID Appliance Documentation â€¢ NetApp Hardware Universe 11'),
#    Document(id='d91bab86-c541-4d2e-a0c7-6f6c38be0b61', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='storage and some management functions, with integrated load balancing to optimize the data load across StorageGRID resources. â€¢ Support for multiple storage tenant accounts to segregate the objects stored on your system by different entities. â€¢')],
#   [Document(id='cb93afbe-1fcb-46c7-86ed-e299b855fdad', metadata={'type': 'text', 'topic': 'Configure and manage a storageGRID system'}, page_content='your data and application environment from the central ONTAP storage system. What is StorageGRID? NetApp StorageGRID is a storage architecture that manages data as objects, as opposed to other storage architectures such as file or block storage.'),
#    Document(id='f9c24a4f-fe09-4060-96e6-9994ed9917e7', metadata={'type': 'text', 'topic': 'Configure and manage a storageGRID system'}, page_content='versions, see the NetApp Interoperability Matrix Tool. Hardening guidelines for StorageGRID networks The StorageGRID system supports up to three network interfaces per grid node, allowing you to configure the networking for each individual grid node'),
#    Document(id='e74e1931-c4a9-430e-829f-c48e241cde8c', metadata={'type': 'text', 'topic': 'Configure and manage a storageGRID system'}, page_content='grid replication and the StorageGRID CloudMirror replication service. Cross-grid replication CloudMirror replication service What is the One StorageGRID system acts as a disaster Enables a tenant to automatically replicate primary recovery system.')],
#   [Document(id='62c51cf1-08be-4855-84e7-51cbb047189d', metadata={'base64_path': 'Extracted_Data\\6.Expand a Grid\\page_20\\page_20_img_1_base64.txt', 'type': 'image', 'topic': 'Expand a Grid'}, page_content='The image shows a screenshot of the StorageGRID system\'s Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a table titled "Disk devices" that lists various disk devices, including their names, worldwide names, I/O load, read rates, write rates, and other relevant information.\n\nBelow this table is another table titled "Volumes" that lists the mount points for each volume, along with their status, size, available space, and write cache status. The bottom section of the image shows a table titled "Object stores" that lists the object stores, including their IDs, sizes, available space, replicated data, EC data, object data percentages, and health status.\n\nOverall, the image provides a comprehensive view of the storage nodes and their associated volumes and object stores, allowing administrators to monitor and manage the system\'s storage capacity and performance.'),
#    Document(id='dd0370fc-6a29-4289-b66d-7894edb16bd6', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the'),
#    Document(id='5aa528c4-e025-4bac-8ad1-bcc09667a33e', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='used to obtain data from the StorageGRID system. It is also used to recover the primary Admin Node. The subnets you have specified are configured automatically for your StorageGRID system. Deploy new grid nodes The steps for deploying new grid nodes')],
#   [Document(id='88bb3b56-1249-4291-ae24-06d8c099d27e', metadata={'base64_path': 'Extracted_Data\\5.Monitor and troubleshoot a storageGRID system\\page_24\\page_24_img_1_base64.txt', 'type': 'image', 'topic': 'Monitor and troubleshoot a storageGRID system'}, page_content='The image shows a screenshot of the Storage tab in the Grid Manager, which displays information about the disk devices and volumes on the services appliance. The top section of the page is titled "DO-REF-DC1-GW1 (Gateway Node)" and features a navigation bar with links to various sections, including Overview, Hardware, Network, Storage, Load balancer, and Tasks.\n\nBelow the navigation bar, there are two tables: one for Disk devices and another for Volumes. The Disk devices table lists the name, world-wide name, I/O load, read rate, write rate, and other details for each disk device. The Volumes table provides information about the mount point, device, status, size, available space, and write cache status for each volume.\n\nAt the bottom of the page, there is a section titled "Network Communication" that displays a graph showing the network traffic received and sent across all network interfaces on the node, site, or grid. The graph can be customized to display different time intervals, such as 1 hour, 1 day, 1 week, or 1 month, or a custom interval can be set using the date and time ranges.\n\nOverall, the image provides a comprehensive overview of the storage and network configuration of the services appliance, allowing administrators to monitor and manage the system\'s performance and resources.'),
#    Document(id='6d43ec93-e96b-4991-90df-3dda7a607d3d', metadata={'base64_path': 'Extracted_Data\\5.Monitor and troubleshoot a storageGRID system\\page_46\\page_46_img_1_base64.txt', 'type': 'image', 'topic': 'Monitor and troubleshoot a storageGRID system'}, page_content='The image presents a comprehensive overview of the storage utilization and capacity of a StorageGRID system, providing detailed information on disk devices, volumes, and object stores. The top section, "Disk devices," lists various disk devices with their respective names, world-wide names, I/O load, read rates, write rates, and available space. Notably, all devices are currently unused, as indicated by the "N/A" values in the I/O load column.\n\nBelow this section, the "Volumes" table displays information on mount points, devices, status, size, available space, and write cache status. The "Object stores" table provides details on ID, size, available space, replicated data, EC data, object data percentage, and health status. The image also includes a series of graphs that illustrate the storage utilization over time, allowing for easy monitoring of the system\'s capacity.\n\nOverall, the image suggests that the StorageGRID system has ample available storage space, with no devices currently in use. However, it is essential to regularly monitor the system\'s capacity to ensure that it can accommodate growing storage needs and maintain normal system operations. By reviewing the available values in the Volumes and Object stores tables and monitoring the graphs over time, administrators can estimate the rate at which usable storage space is being consumed and plan for future expansions accordingly.'),
#    Document(id='b00233f5-c574-471d-aac8-cff0cd64eb3e', metadata={'base64_path': 'Extracted_Data\\5.Monitor and troubleshoot a storageGRID system\\page_222\\page_222_img_1_base64.txt', 'type': 'image', 'topic': 'Monitor and troubleshoot a storageGRID system'}, page_content='The image shows a screenshot of the StorageGRID system\'s dashboard, which displays various metrics and graphs related to network traffic, storage usage, and ILM queue. The top section of the dashboard shows a graph of network traffic over time, with different colors representing different types of traffic (e.g., received, sent). Below this graph are two sections: "Storage Used - Object Data" and "Storage Used - Object Metadata", which display the percentage of storage used for each type of data. The bottom section of the dashboard shows a graph of the ILM queue over time.\n\nOverall, the dashboard provides a comprehensive view of the system\'s performance and usage, allowing administrators to monitor and troubleshoot issues as needed.')]],
#  [[Document(id='547e59bc-4414-4406-a3c0-a76306f24e2f', metadata={'type': 'text', 'topic': 'Recovery or Replace Nodes'}, page_content='the Grid Manager. About this task Object data can be restored from other Storage Nodes, an Archive Node, or a Cloud Storage Pool, assuming that the grid’s ILM rules were configured such that object copies are available. 1603'),
#    Document(id='8a878a3f-73e9-4099-812f-f71107fe0676', metadata={'base64_path': 'Extracted_Data\\8.Recovery or Replace Nodes\\page_75\\page_75_img_1_base64.txt', 'type': 'image', 'topic': 'Recovery or Replace Nodes'}, page_content='The image shows a screenshot of the NetApp StorageGRID installation page, with a blue bar at the top and a white background. The page is divided into two sections: "Welcome" and "Install a StorageGRID system" or "Recover a failed primary Admin Node". \n\nThe "Welcome" section provides instructions on how to use the page to install a new StorageGRID system or recover a failed primary Admin Node for an existing system. It also includes a note about accessing the StorageGRID license, network configuration, and grid topology information, as well as NTP settings to complete the installation.\n\nThe "Install a StorageGRID system" section has a blue icon of a cloud with an arrow pointing up, while the "Recover a failed primary Admin Node" section has a blue icon of a wrench. Both sections have a blue outline around them.\n\nOverall, the image appears to be a screenshot of a web page that provides instructions and options for installing or recovering a StorageGRID system.'),
#    Document(id='2bfd54b1-c206-47d2-b5f2-a9fa8193d31f', metadata={'type': 'text', 'topic': 'Recovery or Replace Nodes'}, page_content='you begin. StorageGRID is a distributed system composed of multiple nodes working with each other. Don’t use disk snapshots to restore grid nodes. Instead, refer to the recovery and maintenance procedures for each type of node. Some of the reasons')],
#   [Document(id='164fa6fe-dd04-4a3a-bb52-9493dc792875', metadata={'base64_path': 'Extracted_Data\\2.Install,Upgrade and hotflix StorageGRID\\page_124\\page_124_img_1_base64.txt', 'type': 'image', 'topic': 'Install,Upgrade and hotflix StorageGRID'}, page_content='The image shows a screenshot of the NetApp StorageGRID installation process, specifically the "Summary" page. The page is divided into two main sections: "General Settings" and "Topology". \n\nIn the "General Settings" section, there are several fields that have been filled in, including:\n\n* Grid Name: Grid1\n* Passwords: Auto-generated random command line passwords\n* Networking: NTP, DNS, Grid Network\n* Topology: Atlanta, Raleigh\n\nAt the top of the page, there is a blue bar with the text "NetApp StorageGRID" in white letters. Below this, there is a series of green circles with numbers inside them, indicating the steps in the installation process. The current step is highlighted in blue, which is step 8, "Summary".\n\nOverall, the image suggests that the user has completed the installation process and is now reviewing the summary of their configuration before finalizing the installation.'),
#    Document(id='0c57c603-9d49-4e18-8b25-28b1b00e225a', metadata={'base64_path': 'Extracted_Data\\2.Install,Upgrade and hotflix StorageGRID\\page_171\\page_171_img_1_base64.txt', 'type': 'image', 'topic': 'Install,Upgrade and hotflix StorageGRID'}, page_content='The image shows a screenshot of the NetApp StorageGRID installation process, specifically the "Summary" page. The page is divided into two main sections: "General Settings" and "Topology".\n\n**General Settings**\n\n* **Grid Name**: Grid1\n* **Passwords**: Auto-generated random command line passwords\n* **Networking**:\n\t+ NTP: 10.60.248.183, 10.227.204.142, 10.235.48.111\n\t+ DNS: 10.224.223.130, 10.224.223.136\n\t+ Grid Network: 172.16.0.0/21\n\n**Topology**\n\n* **Topology**: Atlanta\n* **Raleigh**: dc1-adm1, dc1-g1, dc1-s1, dc1-s2, dc1-s3, NetApp-SGA\n\nThe page also includes a summary of the installation process, including the license, sites, grid network, grid nodes, NTP, DNS, and passwords. Additionally, there are links to modify the grid configuration information and to download the Recovery Package file.\n\nOverall, the image provides a detailed overview of the NetApp StorageGRID installation process and the various settings and configurations that can be customized during the installation.'),
#    Document(id='02903853-7268-46bb-86f1-6feda0b67b23', metadata={'type': 'text', 'topic': 'Install,Upgrade and hotflix StorageGRID'}, page_content='the system. Ensure that these provide adequate disk performance in terms of latency, input/output operations per second (IOPS), and throughput. All StorageGRID nodes require that the OS drive and all storage volumes have write-back caching enabled.')],
#   [Document(id='0c25a14f-dfac-482b-a735-b770b423e0df', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='information and replicate object data between two StorageGRID systems. â€¢ Optionally, enabling the Compress stored objects option. â€¢ Managing S3 Object Lock â€¢ Understanding Storage options such as object segmentation and storage volume'),
#    Document(id='92041416-820b-452a-aac4-d509f4ba6821', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='collect data Work with your NetApp account representative to understand the options and to plan your new StorageGRID system. Consider these types of questions: â€¢ How much object data do you expect to store initially and over time? â€¢ How many'),
#    Document(id='742dad94-b43b-47b0-b397-190e17eeaa11', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.')],
#   [Document(id='dd0370fc-6a29-4289-b66d-7894edb16bd6', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the'),
#    Document(id='62c51cf1-08be-4855-84e7-51cbb047189d', metadata={'base64_path': 'Extracted_Data\\6.Expand a Grid\\page_20\\page_20_img_1_base64.txt', 'type': 'image', 'topic': 'Expand a Grid'}, page_content='The image shows a screenshot of the StorageGRID system\'s Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a table titled "Disk devices" that lists various disk devices, including their names, worldwide names, I/O load, read rates, write rates, and other relevant information.\n\nBelow this table is another table titled "Volumes" that lists the mount points for each volume, along with their status, size, available space, and write cache status. The bottom section of the image shows a table titled "Object stores" that lists the object stores, including their IDs, sizes, available space, replicated data, EC data, object data percentages, and health status.\n\nOverall, the image provides a comprehensive view of the storage nodes and their associated volumes and object stores, allowing administrators to monitor and manage the system\'s storage capacity and performance.'),
#    Document(id='275a28d1-fc4f-4f9c-ad57-bd7a993f206c', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='About this task You must perform expansion operations using the version of StorageGRID that is currently running on the grid. Steps 1. Go to NetApp Downloads: StorageGRID. 2. Select the version of StorageGRID that is currently running on the grid. 3.')]]]

# %%
# Out:
# [[Document(id='3c5e9193-5bf2-4b16-9478-c7f613520c4c', metadata={'type': 'text', 'topic': 'Use StorageGRID tenant and clients'}, page_content='StorageGRID S3 REST API to manage any existing legacy Compliant buckets. • Use S3 REST API to configure S3 Object Lock • Manage objects with ILM • NetApp Knowledge Base: How to manage legacy Compliant buckets in StorageGRID 11.5 Deprecated'), Document(id='3ad6d446-a769-4bc1-995d-66b68f668da0', metadata={'type': 'text', 'topic': 'Use StorageGRID tenant and clients'}, page_content='be saved to several data centers for a certain number of years. Contact your NetApp Professional Services consultant or StorageGRID administrator if you need to understand how the grid’s ILM rules and policies will affect the objects in your Swift'), Document(id='b4b4f649-69de-432f-ba17-e1edb95afcc2', metadata={'base64_path': 'Extracted_Data\\4.UseStorageGRID tenant and clients\\page_4\\page_4_img_1_base64.txt', 'type': 'image', 'topic': 'Use StorageGRID tenant and clients'}, page_content='The image shows a screenshot of the NetApp StorageGRID Grid Manager sign-in page. The page has a white background with black text and blue accents.\n\nAt the top of the page, there is a logo for NetApp StorageGRID, followed by the title "Grid Manager" in large font. Below the title, there are two input fields: one for the username and one for the password. The username field is labeled "Username" and has a placeholder text that reads "|". The password field is labeled "Password" and does not have any placeholder text.\n\nBelow the input fields, there is a blue button that reads "Sign in". To the left of this button, there is a link that reads "Tenant sign in" in blue text within a green rectangle. This link is likely used to access the Tenant Manager sign-in page.\n\nAt the bottom of the page, there are two links: one that reads "NetApp support" and another that reads "NetApp.com". These links are likely used to access additional resources or support information.\n\nOverall, the image appears to be a screenshot of a web-based application used for managing storage grids. The page is designed to allow users to sign in to their accounts using their usernames and passwords.')], [Document(id='742dad94-b43b-47b0-b397-190e17eeaa11', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.'), Document(id='b4a70c6b-86d3-48b9-b16a-56969f447e64', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='to learn about the available appliances: â€¢ StorageGRID Appliance Documentation â€¢ NetApp Hardware Universe 11'), Document(id='92041416-820b-452a-aac4-d509f4ba6821', metadata={'type': 'text', 'topic': 'Get started with StorageGRID system'}, page_content='collect data Work with your NetApp account representative to understand the options and to plan your new StorageGRID system. Consider these types of questions: â€¢ How much object data do you expect to store initially and over time? â€¢ How many')], [Document(id='dd0370fc-6a29-4289-b66d-7894edb16bd6', metadata={'type': 'text', 'topic': 'Expand a Grid'}, page_content='For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the'), Document(id='62c51cf1-08be-4855-84e7-51cbb047189d', metadata={'base64_path': 'Extracted_Data\\6.Expand a Grid\\page_20\\page_20_img_1_base64.txt', 'type': 'image', 'topic': 'Expand a Grid'}, page_content='The image shows a screenshot of the StorageGRID system\'s Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a tabl ...

# %%
context=""

for data in flat_list:
    context=context+"\n"+data.page_content+"\n"+"---------------------------------------------------------------------------------"+"\n"

# %%
print(context)
# Out:
# StorageGRID S3 REST API to manage any existing legacy Compliant buckets. • Use S3 REST API to configure S3 Object Lock • Manage objects with ILM • NetApp Knowledge Base: How to manage legacy Compliant buckets in StorageGRID 11.5 Deprecated
# ---------------------------------------------------------------------------------
#
# be saved to several data centers for a certain number of years. Contact your NetApp Professional Services consultant or StorageGRID administrator if you need to understand how the grid’s ILM rules and policies will affect the objects in your Swift
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the NetApp StorageGRID Grid Manager sign-in page. The page has a white background with black text and blue accents.
#
# At the top of the page, there is a logo for NetApp StorageGRID, followed by the title "Grid Manager" in large font. Below the title, there are two input fields: one for the username and one for the password. The username field is labeled "Username" and has a placeholder text that reads "|". The password field is labeled "Password" and does not have any placeholder text.
#
# Below the input fields, there is a blue button that reads "Sign in". To the left of this button, there is a link that reads "Tenant sign in" in blue text within a green rectangle. This link is likely used to access the Tenant Manager sign-in page.
#
# At the bottom of the page, there are two links: one that reads "NetApp support" and another that reads "NetApp.com". These links are likely used to access additional resources or support information.
#
# Overall, the image appears to be a screenshot of a web-based application used for managing storage grids. The page is designed to allow users to sign in to their accounts using their usernames and passwords.
# ---------------------------------------------------------------------------------
#
# Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.
# ---------------------------------------------------------------------------------
#
# to learn about the available appliances: â€¢ StorageGRID Appliance Documentation â€¢ NetApp Hardware Universe 11
# ---------------------------------------------------------------------------------
#
# collect data Work with your NetApp account representative to understand the options and to plan your new StorageGRID system. Consider these types of questions: â€¢ How much object data do you expect to store initially and over time? â€¢ How many
# ---------------------------------------------------------------------------------
#
# For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the StorageGRID system's Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a table titled "Disk devices" that lists various disk devices, including their names, worldwide names, I/O load, read rates, write rates, and other relevant information.
#
# Below this table is another table titled "Volumes" that lists the mount points for each volume, along with their status, size, available space, and write cache status. The bottom section of the image shows a table titled "Object stores" that lists the object stores, including their IDs, sizes, available space, replicated data, EC data, object data percentages, and health status.
#
# Overall, the image provides a comprehensive view of the storage nodes and their associated volumes and object stores, allowing administrators to monitor and manage the system's storage capacity and performance.
# ---------------------------------------------------------------------------------
#
# About this task You must perform expansion operations using the version of StorageGRID that is currently running on the grid. Steps 1. Go to NetApp Downloads: StorageGRID. 2. Select the version of StorageGRID that is currently running on the grid. 3.
# ---------------------------------------------------------------------------------
#
# Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.
# ---------------------------------------------------------------------------------
#
# to learn about the available appliances: â€¢ StorageGRID Appliance Documentation â€¢ NetApp Hardware Universe 11
# ---------------------------------------------------------------------------------
#
# storage and some management functions, with integrated load balancing to optimize the data load across StorageGRID resources. â€¢ Support for multiple storage tenant accounts to segregate the objects stored on your system by different entities. â€¢
# ---------------------------------------------------------------------------------
#
# your data and application environment from the central ONTAP storage system. What is StorageGRID? NetApp StorageGRID is a storage architecture that manages data as objects, as opposed to other storage architectures such as file or block storage.
# ---------------------------------------------------------------------------------
#
# versions, see the NetApp Interoperability Matrix Tool. Hardening guidelines for StorageGRID networks The StorageGRID system supports up to three network interfaces per grid node, allowing you to configure the networking for each individual grid node
# ---------------------------------------------------------------------------------
#
# grid replication and the StorageGRID CloudMirror replication service. Cross-grid replication CloudMirror replication service What is the One StorageGRID system acts as a disaster Enables a tenant to automatically replicate primary recovery system.
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the StorageGRID system's Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a table titled "Disk devices" that lists various disk devices, including their names, worldwide names, I/O load, read rates, write rates, and other relevant information.
#
# Below this table is another table titled "Volumes" that lists the mount points for each volume, along with their status, size, available space, and write cache status. The bottom section of the image shows a table titled "Object stores" that lists the object stores, including their IDs, sizes, available space, replicated data, EC data, object data percentages, and health status.
#
# Overall, the image provides a comprehensive view of the storage nodes and their associated volumes and object stores, allowing administrators to monitor and manage the system's storage capacity and performance.
# ---------------------------------------------------------------------------------
#
# For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the
# ---------------------------------------------------------------------------------
#
# used to obtain data from the StorageGRID system. It is also used to recover the primary Admin Node. The subnets you have specified are configured automatically for your StorageGRID system. Deploy new grid nodes The steps for deploying new grid nodes
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the Storage tab in the Grid Manager, which displays information about the disk devices and volumes on the services appliance. The top section of the page is titled "DO-REF-DC1-GW1 (Gateway Node)" and features a navigation bar with links to various sections, including Overview, Hardware, Network, Storage, Load balancer, and Tasks.
#
# Below the navigation bar, there are two tables: one for Disk devices and another for Volumes. The Disk devices table lists the name, world-wide name, I/O load, read rate, write rate, and other details for each disk device. The Volumes table provides information about the mount point, device, status, size, available space, and write cache status for each volume.
#
# At the bottom of the page, there is a section titled "Network Communication" that displays a graph showing the network traffic received and sent across all network interfaces on the node, site, or grid. The graph can be customized to display different time intervals, such as 1 hour, 1 day, 1 week, or 1 month, or a custom interval can be set using the date and time ranges.
#
# Overall, the image provides a comprehensive overview of the storage and network configuration of the services appliance, allowing administrators to monitor and manage the system's performance and resources.
# ---------------------------------------------------------------------------------
#
# The image presents a comprehensive overview of the storage utilization and capacity of a StorageGRID system, providing detailed information on disk devices, volumes, and object stores. The top section, "Disk devices," lists various disk devices with their respective names, world-wide names, I/O load, read rates, write rates, and available space. Notably, all devices are currently unused, as indicated by the "N/A" values in the I/O load column.
#
# Below this section, the "Volumes" table displays information on mount points, devices, status, size, available space, and write cache status. The "Object stores" table provides details on ID, size, available space, replicated data, EC data, object data percentage, and health status. The image also includes a series of graphs that illustrate the storage utilization over time, allowing for easy monitoring of the system's capacity.
#
# Overall, the image suggests that the StorageGRID system has ample available storage space, with no devices currently in use. However, it is essential to regularly monitor the system's capacity to ensure that it can accommodate growing storage needs and maintain normal system operations. By reviewing the available values in the Volumes and Object stores tables and monitoring the graphs over time, administrators can estimate the rate at which usable storage space is being consumed and plan for future expansions accordingly.
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the StorageGRID system's dashboard, which displays various metrics and graphs related to network traffic, storage usage, and ILM queue. The top section of the dashboard shows a graph of network traffic over time, with different colors representing different types of traffic (e.g., received, sent). Below this graph are two sections: "Storage Used - Object Data" and "Storage Used - Object Metadata", which display the percentage of storage used for each type of data. The bottom section of the dashboard shows a graph of the ILM queue over time.
#
# Overall, the dashboard provides a comprehensive view of the system's performance and usage, allowing administrators to monitor and troubleshoot issues as needed.
# ---------------------------------------------------------------------------------
#
# the Grid Manager. About this task Object data can be restored from other Storage Nodes, an Archive Node, or a Cloud Storage Pool, assuming that the grid’s ILM rules were configured such that object copies are available. 1603
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the NetApp StorageGRID installation page, with a blue bar at the top and a white background. The page is divided into two sections: "Welcome" and "Install a StorageGRID system" or "Recover a failed primary Admin Node".
#
# The "Welcome" section provides instructions on how to use the page to install a new StorageGRID system or recover a failed primary Admin Node for an existing system. It also includes a note about accessing the StorageGRID license, network configuration, and grid topology information, as well as NTP settings to complete the installation.
#
# The "Install a StorageGRID system" section has a blue icon of a cloud with an arrow pointing up, while the "Recover a failed primary Admin Node" section has a blue icon of a wrench. Both sections have a blue outline around them.
#
# Overall, the image appears to be a screenshot of a web page that provides instructions and options for installing or recovering a StorageGRID system.
# ---------------------------------------------------------------------------------
#
# you begin. StorageGRID is a distributed system composed of multiple nodes working with each other. Don’t use disk snapshots to restore grid nodes. Instead, refer to the recovery and maintenance procedures for each type of node. Some of the reasons
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the NetApp StorageGRID installation process, specifically the "Summary" page. The page is divided into two main sections: "General Settings" and "Topology".
#
# In the "General Settings" section, there are several fields that have been filled in, including:
#
# * Grid Name: Grid1
# * Passwords: Auto-generated random command line passwords
# * Networking: NTP, DNS, Grid Network
# * Topology: Atlanta, Raleigh
#
# At the top of the page, there is a blue bar with the text "NetApp StorageGRID" in white letters. Below this, there is a series of green circles with numbers inside them, indicating the steps in the installation process. The current step is highlighted in blue, which is step 8, "Summary".
#
# Overall, the image suggests that the user has completed the installation process and is now reviewing the summary of their configuration before finalizing the installation.
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the NetApp StorageGRID installation process, specifically the "Summary" page. The page is divided into two main sections: "General Settings" and "Topology".
#
# **General Settings**
#
# * **Grid Name**: Grid1
# * **Passwords**: Auto-generated random command line passwords
# * **Networking**:
# 	+ NTP: 10.60.248.183, 10.227.204.142, 10.235.48.111
# 	+ DNS: 10.224.223.130, 10.224.223.136
# 	+ Grid Network: 172.16.0.0/21
#
# **Topology**
#
# * **Topology**: Atlanta
# * **Raleigh**: dc1-adm1, dc1-g1, dc1-s1, dc1-s2, dc1-s3, NetApp-SGA
#
# The page also includes a summary of the installation process, including the license, sites, grid network, grid nodes, NTP, DNS, and passwords. Additionally, there are links to modify the grid configuration information and to download the Recovery Package file.
#
# Overall, the image provides a detailed overview of the NetApp StorageGRID installation process and the various settings and configurations that can be customized during the installation.
# ---------------------------------------------------------------------------------
#
# the system. Ensure that these provide adequate disk performance in terms of latency, input/output operations per second (IOPS), and throughput. All StorageGRID nodes require that the OS drive and all storage volumes have write-back caching enabled.
# ---------------------------------------------------------------------------------
#
# information and replicate object data between two StorageGRID systems. â€¢ Optionally, enabling the Compress stored objects option. â€¢ Managing S3 Object Lock â€¢ Understanding Storage options such as object segmentation and storage volume
# ---------------------------------------------------------------------------------
#
# collect data Work with your NetApp account representative to understand the options and to plan your new StorageGRID system. Consider these types of questions: â€¢ How much object data do you expect to store initially and over time? â€¢ How many
# ---------------------------------------------------------------------------------
#
# Get started with a StorageGRID system Learn about StorageGRID What is StorageGRID? NetAppÂ® StorageGRIDÂ® is a software-defined object storage suite that supports a wide range of use cases across public, private, and hybrid multicloud environments.
# ---------------------------------------------------------------------------------
#
# For a list of supported versions, see the NetApp Interoperability Matrix Tool (IMT). 4. Perform the expansion. 5. Configure the expanded system. Plan StorageGRID expansion Add storage capacity Guidelines for adding object capacity You can expand the
# ---------------------------------------------------------------------------------
#
# The image shows a screenshot of the StorageGRID system's Grid Manager, which is used to manage and monitor storage nodes. The top section of the image displays a table titled "Disk devices" that lists various disk devices, including their names, worldwide names, I/O load, read rates, write rates, and other relevant information.
#
# Below this table is another table titled "Volumes" that lists the mount points for each volume, along with their status, size, available space, and write cache status. The bottom section of the image shows a table titled "Object stores" that lists the object stores, including their IDs, sizes, available space, replicated data, EC data, object data percentages, and health status.
#
# Overall, the image provides a comprehensive view of the storage nodes and their associated volumes and object stores, allowing administrators to monitor and manage the system's storage capacity and performance.
# ---------------------------------------------------------------------------------
#
# About this task You must perform expansion operations using the version of StorageGRID that is currently running on the grid. Steps 1. Go to NetApp Downloads: StorageGRID. 2. Select the version of StorageGRID that is currently running on the grid. 3.
# ---------------------------------------------------------------------------------

# %%
def final_response(docs,query):
    
    


    prompt=f"""A query/topic is provided along with relevant documents. Your tasks is to answer the query/topic based on the documents provided. 

----------------------------
  query: {query}.
  -----------------------------------
  dcouments: {docs}
  ----------------------------------

Instructions:
1. Be descriptive 
2. Answer only from documents provided
3. Do not use the word "based on documents provided"
    """
    llm = AzureChatOpenAI(
    deployment_name="gpt35",
      api_key="7NfDltek1fOyeUm4UDN9Ng8wmagQxtd54CfuS4TcCk6tvtu8nTrEJQQJ99ALAC4f1cMXJ3w3AAABACOGHgtJ",
        azure_endpoint= "https://expazure-openai.openai.azure.com/",
        temperature=0,
        max_tokens=4096
                )
    output=llm.invoke(prompt)

    return output

# %%
answer=final_response(
    docs=context,query="Compression and deduplication capabilities"
)

# %%
answer
# Out:
# AIMessage(content='The StorageGRID system offers comprehensive capabilities for managing and monitoring storage nodes, volumes, and object stores. The system allows for the configuration of ILM rules and policies to manage objects effectively. Additionally, the system supports the use of S3 REST API for tasks such as configuring S3 Object Lock and managing objects with ILM. The system also provides options for expanding storage capacity and adding object capacity as needed. Overall, StorageGRID offers robust compression and deduplication capabilities to optimize storage efficiency and performance.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 3338, 'total_tokens': 3438, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': 'fp_0165350fbb', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='run-219d7470-e84c-4ab0-a166-bf66e6661cfc-0', usage_metadata={'input_tokens': 3338, 'output_tokens': 100, 'total_tokens': 3438, 'input_token_details': {}, 'output_token_details': {}})
